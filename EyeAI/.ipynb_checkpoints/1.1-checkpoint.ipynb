# %%
import torch
from torch.utils.data import Dataset
from sklearn.model_selection import train_test_split
from torchvision import transforms
from torch.utils.data import DataLoader
import torch.nn as nn
import torch.optim as optim

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %%
import pandas as pd
import os
from torchvision import transforms
from PIL import Image

# %%
paths = []
label_to_idx = {
    'normal':0,
    'diabetic_retinopathy':1,
    'glaucoma':2,
    'cataract':3,
}
idx_to_label = {
    0:'normal',
    1:"diabetic_retinopathy",
    2:'glaucoma',
    3:'cataract'
}
for class_name in os.listdir("dataset"):
    img_paths = os.listdir(f'dataset/{class_name}')
    for img_path in img_paths:
        paths.append((label_to_idx[class_name], os.path.join("dataset",class_name,img_path)))

class CustomDataset(Dataset):
    def __init__(self, paths_list, transform = None):
        super().__init__()
        self.path_list = paths_list
        self.transform = transform

    def __len__(self):
        return len(self.path_list)

    def __getitem__(self, idx):
        class_idx, img_path = self.path_list[idx]
        try:
            with Image.open(img_path) as img:
                img = img.convert("RGB")
                if self.transform:
                    img = self.transform(img)
                return class_idx, img
        except Exception as e:
            print(f"Error loading {img_path}:{str(e)}")
            return None

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    transforms.Resize((512,512))
])

# %%
labels = [item[0] for item in paths]

# %%
labels
# Out:
# [3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  3,
#  ...]

# %%
paths
# Out:
# [(3, 'dataset\\cataract\\0_left.jpg'),
#  (3, 'dataset\\cataract\\103_left.jpg'),
#  (3, 'dataset\\cataract\\1062_right.jpg'),
#  (3, 'dataset\\cataract\\1083_left.jpg'),
#  (3, 'dataset\\cataract\\1084_right.jpg'),
#  (3, 'dataset\\cataract\\1102_left.jpg'),
#  (3, 'dataset\\cataract\\1102_right.jpg'),
#  (3, 'dataset\\cataract\\1115_left.jpg'),
#  (3, 'dataset\\cataract\\1126_right.jpg'),
#  (3, 'dataset\\cataract\\112_right.jpg'),
#  (3, 'dataset\\cataract\\1144_left.jpg'),
#  (3, 'dataset\\cataract\\1144_right.jpg'),
#  (3, 'dataset\\cataract\\1164_left.jpg'),
#  (3, 'dataset\\cataract\\1167_right.jpg'),
#  (3, 'dataset\\cataract\\119_left.jpg'),
#  (3, 'dataset\\cataract\\1285_left.jpg'),
#  (3, 'dataset\\cataract\\1415_left.jpg'),
#  (3, 'dataset\\cataract\\1415_right.jpg'),
#  (3, 'dataset\\cataract\\1435_left.jpg'),
#  (3, 'dataset\\cataract\\1444_left.jpg'),
#  (3, 'dataset\\cataract\\1452_left.jpg'),
#  (3, 'dataset\\cataract\\1454_right.jpg'),
#  (3, 'dataset\\cataract\\1456_left.jpg'),
#  (3, 'dataset\\cataract\\1460_right.jpg'),
#  (3, 'dataset\\cataract\\1468_left.jpg'),
#  (3, 'dataset\\cataract\\1483_right.jpg'),
#  (3, 'dataset\\cataract\\1484_left.jpg'),
#  (3, 'dataset\\cataract\\1484_right.jpg'),
#  (3, 'dataset\\cataract\\1490_right.jpg'),
#  (3, 'dataset\\cataract\\188_right.jpg'),
#  (3, 'dataset\\cataract\\1968_left.jpg'),
#  (3, 'dataset\\cataract\\1987_left.jpg'),
#  (3, 'dataset\\cataract\\1994_left.jpg'),
#  (3, 'dataset\\cataract\\2052_left.jpg'),
#  (3, 'dataset\\cataract\\2052_right.jpg'),
#  (3, 'dataset\\cataract\\2074_right.jpg'),
#  (3, 'dataset\\cataract\\2095_right.jpg'),
#  (3, 'dataset\\cataract\\2096_right.jpg'),
#  (3, 'dataset\\cataract\\2097_right.jpg'),
#  (3, 'dataset\\cataract\\2098_left.jpg'),
#  (3, 'dataset\\cataract\\2098_right.jpg'),
#  (3, 'dataset\\cataract\\2099_left.jpg'),
#  (3, 'dataset\\cataract\\2100_right.jpg'),
#  (3, 'dataset\\cataract\\2101_left.jpg'),
#  (3, 'dataset\\cataract\\2101_right.jpg'),
#  (3, 'dataset\\cataract\\2103_left.jpg'),
#  (3, 'dataset\\cataract\\2103_right.jpg'),
#  (3, 'dataset\\cataract\\2104_left.jpg'),
#  (3, 'dataset\\cataract\\2104_right.jpg'),
#  (3, 'dataset\\cataract\\2105_left.jpg'),
#  (3, 'dataset\\cataract\\2105_right.jpg'),
#  (3, 'dataset\\cataract\\2106_right.jpg'),
#  (3, 'dataset\\cataract\\2107_left.jpg'),
#  (3, 'dataset\\cataract\\2108_left.jpg'),
#  (3, 'dataset\\cataract\\2108_right.jpg'),
#  (3, 'dataset\\cataract\\2109_left.jpg'),
#  (3, 'dataset\\cataract\\2109_right.jpg'),
#  (3, 'dataset\\cataract\\2110_left.jpg'),
#  (3, 'dataset\\cataract\\2110_right.jpg'),
#  (3, 'dataset\\cataract\\2111_left.jpg'),
#  (3, 'dataset\\cataract\\2113_left.jpg'),
#  (3, 'dataset\\cataract\\2113_right.jpg'),
#  (3, 'dataset\\cataract\\2114_left.jpg'),
#  (3, 'dataset\\cataract\\2114_right.jpg'),
#  (3, 'dataset\\cataract\\2115_right.jpg'),
#  (3, 'dataset\\cataract\\2116_left.jpg'),
#  (3, 'dataset\\cataract\\2116_right.jpg'),
#  (3, 'dataset\\cataract\\2117_left.jpg'),
#  (3, 'dataset\\cataract\\2118_right.jpg'),
#  (3, 'dataset\\cataract\\2119_right.jpg'),
#  (3, 'dataset\\cataract\\2120_left.jpg'),
#  (3, 'dataset\\cataract\\2120_right.jpg'),
#  (3, 'dataset\\cataract\\2121_left.jpg'),
#  (3, 'dataset\\cataract\\2122_left.jpg'),
#  (3, 'dataset\\cataract\\2122_right.jpg'),
#  (3, 'dataset\\cataract\\2123_left.jpg'),
#  (3, 'dataset\\cataract\\2124_left.jpg'),
#  (3, 'dataset\\cataract\\2125_left.jpg'),
#  (3, 'dataset\\cataract\\2126_left.jpg'),
#  (3, 'dataset\\cataract\\2126_right.jpg'),
#  (3, 'dataset\\cataract\\2127_left.jpg'),
#  (3, 'dataset\\cataract\\2127_right.jpg'),
#  (3, 'dataset\\cataract\\2128_left.jpg'),
#  (3, 'dataset\\cataract\\2128_right.jpg'),
#  (3, 'dataset\\cataract\\2129_left.jpg'),
#  (3, 'dataset\\cataract\\2129_right.jpg'),
#  (3, 'dataset\\cataract\\2130_left.jpg'),
#  (3, 'dataset\\cataract\\2130_right.jpg'),
#  (3, 'dataset\\cataract\\2132_left.jpg'),
#  (3, 'dataset\\cataract\\2133_left.jpg'),
#  (3, 'dataset\\cataract\\2133_right.jpg'),
#  (3, 'dataset\\cataract\\2134_left.jpg'),
#  (3, 'dataset\\cataract\\2134_right.jpg'),
#  (3, 'dataset\\cataract\\2135_left.jpg'),
#  (3, 'dataset\\cataract\\2135_right.jpg'),
#  (3, 'dataset\\cataract\\2136_left.jpg'),
#  (3, 'dataset\\cataract\\2137_left.jpg'),
#  (3, 'dataset\\cataract\\2137_right.jpg'),
#  (3, 'dataset\\cataract\\2138_left.jpg'),
#  (3, 'dataset\\cataract\\2138_right.jpg'),
#  (3, 'dataset\\cataract\\2139_right.jpg'),
#  (3, 'dataset\\cataract\\2140_left.jpg'),
#  (3, 'dataset\\cataract\\2140_right.jpg'),
#  (3, 'dataset\\cataract\\2141_right.jpg'),
#  (3, 'dataset\\cataract\\2142_left.jpg'),
#  (3, 'dataset\\cataract\\2142_right.jpg'),
#  (3, 'dataset\\cataract\\2143_right.jpg'),
#  (3, 'dataset\\cataract\\2144_left.jpg'),
#  (3, 'dataset\\cataract\\2144_right.jpg'),
#  (3, 'dataset\\cataract\\2145_left.jpg'),
#  (3, 'dataset\\cataract\\2146_left.jpg'),
#  (3, 'dataset\\cataract\\2146_right.jpg'),
#  (3, 'dataset\\cataract\\2147_left.jpg'),
#  (3, 'dataset\\cataract\\2149_right.jpg'),
#  (3, 'dataset\\cataract\\2150_left.jpg'),
#  (3, 'dataset\\cataract\\2150_right.jpg'),
#  (3, 'dataset\\cataract\\2151_left.jpg'),
#  (3, 'dataset\\cataract\\2151_right.jpg'),
#  (3, 'dataset\\cataract\\2152_left.jpg'),
#  (3, 'dataset\\cataract\\2153_left.jpg'),
#  (3, 'dataset\\cataract\\2153_right.jpg'),
#  (3, 'dataset\\cataract\\2154_left.jpg'),
#  (3, 'dataset\\cataract\\2155_left.jpg'),
#  (3, 'dataset\\cataract\\2155_right.jpg'),
#  (3, 'dataset\\cataract\\2156_left.jpg'),
#  (3, 'dataset\\cataract\\2157_left.jpg'),
#  (3, 'dataset\\cataract\\2157_right.jpg'),
#  (3, 'dataset\\cataract\\2158_left.jpg'),
#  (3, 'dataset\\cataract\\2158_right.jpg'),
#  (3, 'dataset\\cataract\\2159_left.jpg'),
#  (3, 'dataset\\cataract\\2160_right.jpg'),
#  (3, 'dataset\\cataract\\2161_right.jpg'),
#  (3, 'dataset\\cataract\\2162_right.jpg'),
#  (3, 'dataset\\cataract\\2163_left.jpg'),
#  (3, 'dataset\\cataract\\2163_right.jpg'),
#  (3, 'dataset\\cataract\\2164_left.jpg'),
#  (3, 'dataset\\cataract\\2164_right.jpg'),
#  (3, 'dataset\\cataract\\2165_right.jpg'),
#  (3, 'dataset\\cataract\\2166_left.jpg'),
#  (3, 'dataset\\cataract\\2167_left.jpg'),
#  (3, 'dataset\\cataract\\2167_right.jpg'),
#  (3, 'dataset\\cataract\\2168_left.jpg'),
#  (3, 'dataset\\cataract\\2168_right.jpg'),
#  (3, 'dataset\\cataract\\2169_left.jpg'),
#  (3, 'dataset\\cataract\\2169_right.jpg'),
#  (3, 'dataset\\cataract\\2170_left.jpg'),
#  (3, 'dataset\\cataract\\2170_right.jpg'),
#  (3, 'dataset\\cataract\\2171_left.jpg'),
#  (3, 'dataset\\cataract\\2172_left.jpg'),
#  (3, 'dataset\\cataract\\2173_right.jpg'),
#  (3, 'dataset\\cataract\\2174_right.jpg'),
#  (3, 'dataset\\cataract\\2175_left.jpg'),
#  (3, 'dataset\\cataract\\2176_left.jpg'),
#  (3, 'dataset\\cataract\\2176_right.jpg'),
#  (3, 'dataset\\cataract\\2177_right.jpg'),
#  (3, 'dataset\\cataract\\2178_left.jpg'),
#  (3, 'dataset\\cataract\\2178_right.jpg'),
#  (3, 'dataset\\cataract\\2179_left.jpg'),
#  (3, 'dataset\\cataract\\2179_right.jpg'),
#  (3, 'dataset\\cataract\\2180_left.jpg'),
#  (3, 'dataset\\cataract\\2180_right.jpg'),
#  (3, 'dataset\\cataract\\2181_left.jpg'),
#  (3, 'dataset\\cataract\\2181_right.jpg'),
#  (3, 'dataset\\cataract\\2182_left.jpg'),
#  (3, 'dataset\\cataract\\2182_right.jpg'),
#  (3, 'dataset\\cataract\\2183_left.jpg'),
#  (3, 'dataset\\cataract\\2183_right.jpg'),
#  (3, 'dataset\\cataract\\2184_left.jpg'),
#  (3, 'dataset\\cataract\\2184_right.jpg'),
#  (3, 'dataset\\cataract\\2185_left.jpg'),
#  (3, 'dataset\\cataract\\2187_right.jpg'),
#  (3, 'dataset\\cataract\\2189_left.jpg'),
#  (3, 'dataset\\cataract\\2189_right.jpg'),
#  (3, 'dataset\\cataract\\218_right.jpg'),
#  (3, 'dataset\\cataract\\2190_right.jpg'),
#  (3, 'dataset\\cataract\\2191_right.jpg'),
#  (3, 'dataset\\cataract\\2192_left.jpg'),
#  (3, 'dataset\\cataract\\2192_right.jpg'),
#  (3, 'dataset\\cataract\\2193_right.jpg'),
#  (3, 'dataset\\cataract\\2194_left.jpg'),
#  (3, 'dataset\\cataract\\2194_right.jpg'),
#  (3, 'dataset\\cataract\\2195_left.jpg'),
#  (3, 'dataset\\cataract\\2195_right.jpg'),
#  (3, 'dataset\\cataract\\2196_right.jpg'),
#  (3, 'dataset\\cataract\\2197_right.jpg'),
#  (3, 'dataset\\cataract\\2198_left.jpg'),
#  (3, 'dataset\\cataract\\2198_right.jpg'),
#  (3, 'dataset\\cataract\\2199_left.jpg'),
#  (3, 'dataset\\cataract\\2200_left.jpg'),
#  (3, 'dataset\\cataract\\2201_right.jpg'),
#  (3, 'dataset\\cataract\\2203_left.jpg'),
#  (3, 'dataset\\cataract\\2203_right.jpg'),
#  (3, 'dataset\\cataract\\2204_left.jpg'),
#  (3, 'dataset\\cataract\\2205_right.jpg'),
#  (3, 'dataset\\cataract\\2206_left.jpg'),
#  (3, 'dataset\\cataract\\2206_right.jpg'),
#  (3, 'dataset\\cataract\\2207_left.jpg'),
#  (3, 'dataset\\cataract\\2207_right.jpg'),
#  (3, 'dataset\\cataract\\2208_right.jpg'),
#  (3, 'dataset\\cataract\\2209_left.jpg'),
#  (3, 'dataset\\cataract\\2209_right.jpg'),
#  (3, 'dataset\\cataract\\2210_left.jpg'),
#  (3, 'dataset\\cataract\\2210_right.jpg'),
#  (3, 'dataset\\cataract\\2211_left.jpg'),
#  (3, 'dataset\\cataract\\2211_right.jpg'),
#  (3, 'dataset\\cataract\\2212_left.jpg'),
#  (3, 'dataset\\cataract\\2212_right.jpg'),
#  (3, 'dataset\\cataract\\2213_left.jpg'),
#  (3, 'dataset\\cataract\\2213_right.jpg'),
#  (3, 'dataset\\cataract\\2215_left.jpg'),
#  (3, 'dataset\\cataract\\2216_left.jpg'),
#  (3, 'dataset\\cataract\\2216_right.jpg'),
#  (3, 'dataset\\cataract\\2217_left.jpg'),
#  (3, 'dataset\\cataract\\2217_right.jpg'),
#  (3, 'dataset\\cataract\\2218_right.jpg'),
#  (3, 'dataset\\cataract\\2219_left.jpg'),
#  (3, 'dataset\\cataract\\2219_right.jpg'),
#  (3, 'dataset\\cataract\\2220_right.jpg'),
#  (3, 'dataset\\cataract\\2221_left.jpg'),
#  (3, 'dataset\\cataract\\2221_right.jpg'),
#  (3, 'dataset\\cataract\\2222_left.jpg'),
#  (3, 'dataset\\cataract\\2223_left.jpg'),
#  (3, 'dataset\\cataract\\2223_right.jpg'),
#  (3, 'dataset\\cataract\\2225_left.jpg'),
#  (3, 'dataset\\cataract\\2225_right.jpg'),
#  (3, 'dataset\\cataract\\2226_left.jpg'),
#  (3, 'dataset\\cataract\\2226_right.jpg'),
#  (3, 'dataset\\cataract\\2227_left.jpg'),
#  (3, 'dataset\\cataract\\2227_right.jpg'),
#  (3, 'dataset\\cataract\\2228_right.jpg'),
#  (3, 'dataset\\cataract\\2229_left.jpg'),
#  (3, 'dataset\\cataract\\2231_right.jpg'),
#  (3, 'dataset\\cataract\\2232_left.jpg'),
#  (3, 'dataset\\cataract\\2232_right.jpg'),
#  (3, 'dataset\\cataract\\2233_left.jpg'),
#  (3, 'dataset\\cataract\\2233_right.jpg'),
#  (3, 'dataset\\cataract\\2234_left.jpg'),
#  (3, 'dataset\\cataract\\2234_right.jpg'),
#  (3, 'dataset\\cataract\\2235_left.jpg'),
#  (3, 'dataset\\cataract\\2236_left.jpg'),
#  (3, 'dataset\\cataract\\2236_right.jpg'),
#  (3, 'dataset\\cataract\\2237_right.jpg'),
#  (3, 'dataset\\cataract\\2239_left.jpg'),
#  (3, 'dataset\\cataract\\2239_right.jpg'),
#  (3, 'dataset\\cataract\\2240_left.jpg'),
#  (3, 'dataset\\cataract\\2240_right.jpg'),
#  (3, 'dataset\\cataract\\2241_left.jpg'),
#  (3, 'dataset\\cataract\\2242_left.jpg'),
#  (3, 'dataset\\cataract\\2242_right.jpg'),
#  (3, 'dataset\\cataract\\2243_left.jpg'),
#  (3, 'dataset\\cataract\\2243_right.jpg'),
#  (3, 'dataset\\cataract\\2244_right.jpg'),
#  (3, 'dataset\\cataract\\2246_left.jpg'),
#  (3, 'dataset\\cataract\\2246_right.jpg'),
#  (3, 'dataset\\cataract\\2247_left.jpg'),
#  (3, 'dataset\\cataract\\2247_right.jpg'),
#  (3, 'dataset\\cataract\\2248_left.jpg'),
#  (3, 'dataset\\cataract\\2248_right.jpg'),
#  (3, 'dataset\\cataract\\2251_right.jpg'),
#  (3, 'dataset\\cataract\\2262_left.jpg'),
#  (3, 'dataset\\cataract\\2282_right.jpg'),
#  (3, 'dataset\\cataract\\24_right.jpg'),
#  (3, 'dataset\\cataract\\254_left.jpg'),
#  (3, 'dataset\\cataract\\294_left.jpg'),
#  (3, 'dataset\\cataract\\330_left.jpg'),
#  (3, 'dataset\\cataract\\345_right.jpg'),
#  (3, 'dataset\\cataract\\354_right.jpg'),
#  (3, 'dataset\\cataract\\448_left.jpg'),
#  (3, 'dataset\\cataract\\465_left.jpg'),
#  (3, 'dataset\\cataract\\477_left.jpg'),
#  (3, 'dataset\\cataract\\477_right.jpg'),
#  (3, 'dataset\\cataract\\553_left.jpg'),
#  (3, 'dataset\\cataract\\553_right.jpg'),
#  (3, 'dataset\\cataract\\560_left.jpg'),
#  (3, 'dataset\\cataract\\560_right.jpg'),
#  (3, 'dataset\\cataract\\594_left.jpg'),
#  (3, 'dataset\\cataract\\611_left.jpg'),
#  (3, 'dataset\\cataract\\625_left.jpg'),
#  (3, 'dataset\\cataract\\625_right.jpg'),
#  (3, 'dataset\\cataract\\629_left.jpg'),
#  (3, 'dataset\\cataract\\691_left.jpg'),
#  (3, 'dataset\\cataract\\726_left.jpg'),
#  (3, 'dataset\\cataract\\726_right.jpg'),
#  (3, 'dataset\\cataract\\750_left.jpg'),
#  (3, 'dataset\\cataract\\769_right.jpg'),
#  (3, 'dataset\\cataract\\809_left.jpg'),
#  (3, 'dataset\\cataract\\81_left.jpg'),
#  (3, 'dataset\\cataract\\81_right.jpg'),
#  (3, 'dataset\\cataract\\820_left.jpg'),
#  (3, 'dataset\\cataract\\824_left.jpg'),
#  (3, 'dataset\\cataract\\874_left.jpg'),
#  (3, 'dataset\\cataract\\907_left.jpg'),
#  (3, 'dataset\\cataract\\949_right.jpg'),
#  (3, 'dataset\\cataract\\955_right.jpg'),
#  (3, 'dataset\\cataract\\970_left.jpg'),
#  (3, 'dataset\\cataract\\970_right.jpg'),
#  (3, 'dataset\\cataract\\999_left.jpg'),
#  (3, 'dataset\\cataract\\999_right.jpg'),
#  (3, 'dataset\\cataract\\cataract_001.png'),
#  (3, 'dataset\\cataract\\cataract_002.png'),
#  (3, 'dataset\\cataract\\cataract_003.png'),
#  (3, 'dataset\\cataract\\cataract_004.png'),
#  (3, 'dataset\\cataract\\cataract_005.png'),
#  (3, 'dataset\\cataract\\cataract_006.png'),
#  (3, 'dataset\\cataract\\cataract_007.png'),
#  (3, 'dataset\\cataract\\cataract_008.png'),
#  (3, 'dataset\\cataract\\_63_4246818.jpg'),
#  (3, 'dataset\\cataract\\_63_7923836.jpg'),
#  (3, 'dataset\\cataract\\_64_2615880.jpg'),
#  (3, 'dataset\\cataract\\_64_5229674.jpg'),
#  (3, 'dataset\\cataract\\_65_5167591.jpg'),
#  (3, 'dataset\\cataract\\_66_625523.jpg'),
#  (3, 'dataset\\cataract\\_66_9729796.jpg'),
#  (3, 'dataset\\cataract\\_67_2701502.jpg'),
#  (3, 'dataset\\cataract\\_67_7544085.jpg'),
#  (3, 'dataset\\cataract\\_68_132563.jpg'),
#  (3, 'dataset\\cataract\\_68_6182618.jpg'),
#  (3, 'dataset\\cataract\\_69_3198217.jpg'),
#  (3, 'dataset\\cataract\\_69_4758198.jpg'),
#  (3, 'dataset\\cataract\\_6_4834075.jpg'),
#  (3, 'dataset\\cataract\\_6_6261868.jpg'),
#  (3, 'dataset\\cataract\\_70_3464173.jpg'),
#  (3, 'dataset\\cataract\\_70_6811978.jpg'),
#  (3, 'dataset\\cataract\\_71_5079718.jpg'),
#  (3, 'dataset\\cataract\\_71_7808711.jpg'),
#  (3, 'dataset\\cataract\\_72_6009084.jpg'),
#  (3, 'dataset\\cataract\\_72_8796984.jpg'),
#  (3, 'dataset\\cataract\\_73_1828688.jpg'),
#  (3, 'dataset\\cataract\\_74_5402652.jpg'),
#  (3, 'dataset\\cataract\\_75_6801378.jpg'),
#  (3, 'dataset\\cataract\\_76_3327192.jpg'),
#  (3, 'dataset\\cataract\\_77_2197698.jpg'),
#  (3, 'dataset\\cataract\\_77_938150.jpg'),
#  ...]

# %%
train_paths, test_paths = train_test_split(paths, stratify = labels, test_size = 0.25)

# %%
train_dataset = CustomDataset(train_paths, transform = transform)
test_dataset = CustomDataset(test_paths, transform = transform)

# %%
train_loader = DataLoader(train_dataset, batch_size = 4, shuffle = True, pin_memory = True)
test_loader = DataLoader(test_dataset, batch_size = 4, shuffle = False, pin_memory = True)

# %%
next(iter(train_loader))
# Out:
# [tensor([1, 2, 2, 1]),
#  tensor([[[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            ...,
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#           [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            ...,
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#           [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            ...,
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]],
#
#
#          [[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            ...,
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#           [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            ...,
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#           [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            ...,
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]],
#
#
#          [[[-2.1118, -2.1157, -2.1125,  ..., -2.1177, -2.1172, -2.1153],
#            [-2.1174, -2.1167, -2.1133,  ..., -2.1170, -2.1167, -2.1131],
#            [-2.1130, -2.1116, -2.1171,  ..., -2.1171, -2.1168, -2.1159],
#            ...,
#            [-2.1156, -2.1177, -2.1173,  ..., -2.1178, -2.1136, -2.1157],
#            [-2.1122, -2.1144, -2.1178,  ..., -2.1157, -2.1175, -2.1141],
#            [-2.1166, -2.1120, -2.1174,  ..., -2.1144, -2.1152, -2.1163]],
#
#           [[-2.0295, -2.0335, -2.0301,  ..., -2.0324, -2.0335, -2.0331],
#            [-2.0352, -2.0345, -2.0311,  ..., -2.0340, -2.0339, -2.0308],
#            [-2.0308, -2.0293, -2.0349,  ..., -2.0329, -2.0357, -2.0337],
#            ...,
#            [-2.0335, -2.0339, -2.0311,  ..., -2.0356, -2.0313, -2.0334],
#            [-2.0299, -2.0322, -2.0356,  ..., -2.0334, -2.0353, -2.0318],
#            [-2.0344, -2.0296, -2.0352,  ..., -2.0321, -2.0329, -2.0341]],
#
#           [[-1.7983, -1.8022, -1.7989,  ..., -1.8030, -1.8023, -1.8018],
#            [-1.8040, -1.8032, -1.7998,  ..., -1.8030, -1.8026, -1.7996],
#            [-1.7995, -1.7981, -1.8037,  ..., -1.8022, -1.8044, -1.8024],
#            ...,
#            [-1.8022, -1.8034, -1.8010,  ..., -1.8043, -1.8000, -1.8022],
#            [-1.7987, -1.8009, -1.8044,  ..., -1.8022, -1.8040, -1.8006],
#            [-1.8031, -1.7984, -1.8039,  ..., -1.8009, -1.8017, -1.8028]]],
#
#
#          [[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            ...,
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#            [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#           [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            ...,
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#            [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#           [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            ...,
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#            [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]]])]

# %%
class CNN(nn.Module):
    def __init__(self, inp_dim=3):
        super().__init__()
        
        self.features = nn.Sequential(
            nn.Conv2d(inp_dim, 32, kernel_size = 3, padding = "same"),
            nn.ReLU(),
            nn.BatchNorm2d(32),
            nn.MaxPool2d(kernel_size = 2, stride = 2),

            nn.Conv2d(32, 64, kernel_size = 3, padding = "same"),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size = 2, stride = 2),
            
            nn.Conv2d(64, 64, kernel_size = 3, padding = "same"),
            nn.ReLU(),
            nn.BatchNorm2d(64),
            nn.MaxPool2d(kernel_size = 2, stride = 2),
        )
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64*64*64, 128),
            nn.ReLU(),
            nn.Dropout(0.4),

            nn.Linear(128,256),
            nn.ReLU(),
            nn.Dropout(0.4),

            nn.Linear(256,4),
        )

    def forward(self, X):
        x = self.features(X)
        x = self.classifier(x)
        return x

# %%
lr = 1e-3
epochs = 10

# %%
model = CNN(3)
model.to(device)

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr = lr, weight_decay = 1e-4)

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 model.summary()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1940, in Module.__getattr__(self, name)
#    1938     if name in modules:
#    1939         return modules[name]
# -> 1940 raise AttributeError(
#    1941     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1942 )
#
# AttributeError: 'CNN' object has no attribute 'summary'

# %%
# %%time
for epoch in range(epochs):
    total_epoch_loss = 0
    for batch_labels,batch_features in train_loader:
        batch_labels = batch_labels.to(device)
        batch_features = batch_features.to(device)

        y_pred = model(batch_features)
        loss = loss_fn(y_pred, batch_labels)
        total_epoch_loss += loss.item()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    avg_epoch_loss = total_epoch_loss/len(train_loader)
    print(f"Epoch:{epoch+1}, Loss:{avg_epoch_loss}")
# Out:
# Epoch:1, Loss:0.3661398876721811
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:3
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py:733, in _BaseDataLoaderIter.__next__(self)
#     730 if self._sampler_iter is None:
#     731     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732     self._reset()  # type: ignore[call-arg]
# --> 733 data = self._next_data()
#     734 self._num_yielded += 1
#     735 if (
#     736     self._dataset_kind == _DatasetKind.Iterable
#     737     and self._IterableDataset_len_called is not None
#     738     and self._num_yielded > self._IterableDataset_len_called
#     739 ):
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\dataloader.py:789, in _SingleProcessDataLoaderIter._next_data(self)
#     787 def _next_data(self):
#     788     index = self._next_index()  # may raise StopIteration
# --> 789     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     790     if self._pin_memory:
#     791         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[18], line 32, in CustomDataset.__getitem__(self, idx)
#      30 try:
#      31     with Image.open(img_path) as img:
# ---> 32         img = img.convert("RGB")
#      33         if self.transform:
#      34             img = self.transform(img)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\Image.py:995, in Image.convert(self, mode, matrix, dither, palette, colors)
#     992 if mode in ("BGR;15", "BGR;16", "BGR;24"):
#     993     deprecate(mode, 12)
# --> 995 self.load()
#     997 has_transparency = "transparency" in self.info
#     998 if not mode and self.mode == "P":
#     999     # determine default mode
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\PIL\ImageFile.py:293, in ImageFile.load(self)
#     290         raise OSError(msg)
#     292 b = b + s
# --> 293 n, err_code = decoder.decode(b)
#     294 if n < 0:
#     295     break
#
# KeyboardInterrupt:

# %%
model.eval()
# Out:
# CNN(
#   (features): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (5): ReLU()
#     (6): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=1048576, out_features=128, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.4, inplace=False)
#     (4): Linear(in_features=128, out_features=256, bias=True)
#     (5): ReLU()
#     (6): Dropout(p=0.4, inplace=False)
#     (7): Linear(in_features=256, out_features=4, bias=True)
#   )
# )

# %%
total = 0
correct = 0


with torch.no_grad():
    for batch_labels,batch_features in test_loader:
        batch_features,batch_labels = batch_features.to(device),batch_labels.to(device)
        outputs = model(batch_features)
        _, y_pred = torch.max(outputs, 1)
        total += batch_labels.shape[0]
        correct += (batch_labels == y_pred).sum().item()
print(correct/total)
# Out:
# 0.8009478672985783

# %%
total = 0
correct = 0


with torch.no_grad():
    for batch_labels,batch_features in train_loader:
        batch_features,batch_labels = batch_features.to(device),batch_labels.to(device)
        outputs = model(batch_features)
        _, y_pred = torch.max(outputs, 1)
        total += batch_labels.shape[0]
        correct += (batch_labels == y_pred).sum().item()
print(correct/total)
# Out:
# 0.8823529411764706

# %%
torch.save({
    "model_state_dict": model.state_dict(),
    "label_to_idx": label_to_idx,
    "idx_to_label":idx_to_label,
    "input_size": (3,512,512)
}, "fundus_classifier(test-0.80,train-0.88).pth")

# %%
def get_model_checksum(model):
    checksums = {}
    for name, param in model.named_parameters():
        checksums[name] = torch.sum(param.data).item()  # Sum of all weights
    return checksums

# %%
get_model_checksum(model)
# Out:
# {'features.0.weight': -1.2373850345611572,
#  'features.0.bias': -0.3825535774230957,
#  'features.2.weight': 31.934707641601562,
#  'features.2.bias': 0.10816515982151031,
#  'features.4.weight': -8.891368865966797,
#  'features.4.bias': -0.7057496905326843,
#  'features.6.weight': 63.11931610107422,
#  'features.6.bias': -0.245407372713089,
#  'classifier.1.weight': -1774.312744140625,
#  'classifier.1.bias': 0.0006313369958661497,
#  'classifier.4.weight': -22.28335189819336,
#  'classifier.4.bias': 0.014752909541130066,
#  'classifier.7.weight': -1.3893972635269165,
#  'classifier.7.bias': 0.0967721939086914}
